# %%
print('hello world')
# Out:
# hello world

# %%
import cv2
import matplotlib.pyplot

# %%
zo = cv2.imread('zo.jpg')

# %%
cv2.imshow('image', zo)

# %%
cv2.waitKey(0)
# Out:
# 13

# %%
matplotlib.pyplot.imshow(zo)
matplotlib.pyplot.title('my picture')
matplotlib.pyplot.show()

# %%
cv2.destroyAllWindows()
